# %%
# %matplotlib inline

# %%
import math
import random
import statistics as st
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from advanced import *

# %%
tron = Simulation([33], 480, 1, .1)

# %%
tron.plot_traffic(tron.get_location(33, 480))

# %%
tron = Simulation([33], 480, 1, .9)

# %%
tron.plot_traffic(tron.get_location(33, 480))

# %%
tronss = Simulation(range(20,33), 480, 100, .1)

# %%
speeds_list, average_speeds_list = tronss.full_monte()

# %%
avg_speeds_by_max_speed = []
for i, speed in enumerate(average_speeds_list):
    avg_speed = i + 20, st.mean(speed), st.stdev(speed)
    print(avg_speed)
    avg_speeds_by_max_speed.append(avg_speed)
# Out:
# (20, 16.2354, 0.44543117234083324)
# (21, 17.9265, 0.524751745056073)
# (22, 18.0619, 0.44382791960648693)
# (23, 19.464100000000002, 0.638824828584614)
# (24, 19.5631, 0.661799956042747)
# (25, 21.1511, 0.772439262428713)
# (26, 21.0923, 0.7489977882935885)
# (27, 22.6527, 0.8747361564691053)
# (28, 22.798099999999998, 0.795905805045453)
# (29, 24.268600000000003, 1.0002535234184937)
# (30, 24.302, 0.8963247066760904)
# (31, 25.6688, 1.145826224771338)
# (32, 25.453699999999998, 1.210211313879698)
